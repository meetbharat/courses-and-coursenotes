# %% [markdown]
# # Basic Analysis

# %%
import pandas as pd

# %%
oo = pd.read_csv('olympics.csv',skiprows = 4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ### value_counts()

# %%
# Medals by Edition

oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts(ascending=True,dropna=False)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %% [markdown]
# ### sort_values()

# %%
ath = oo.Athlete.sort_values()
ath
# Out:
# 651                    AABYE, Edgar
# 2849          AALTONEN, Arvo Ossian
# 2852          AALTONEN, Arvo Ossian
# 7716       AALTONEN, Paavo Johannes
# 7730       AALTONEN, Paavo Johannes
# 7773       AALTONEN, Paavo Johannes
# 7709       AALTONEN, Paavo Johannes
# 8563       AALTONEN, Paavo Johannes
# 28460              AAMODT, Ragnhild
# 3436               AANING, Alf Lied
# 19062         AARDENBURG, Willemien
# 22769             AARDEWIJN, Pepijn
# 22267          AARONES, Ann Kristin
# 3437                  AAS, Karl Jan
# 2601           AAS, Thomas Valentin
# 28134              ABAJO, Jose Luis
# 27691              ABAKUMOVA, Maria
# 27983           ABALMASAU, Aliaksei
# 28417                    ABALO, Luc
# 24202         ABANDA ETONG, Patrice
# 21538            ABARCA, Jose Maria
# 27125                 ABAS, Stephen
# 16390     ABASCAL GARCIA, Alejandro
# 16806    ABASCAL GOMEZ, Jose Manuel
# 26049             ABASSOVA, Tamilla
# 28418                   ABATI, Joel
# ...

# %%
# sorted by Edition and Athlete

oo.sort_values(by=['Edition','Athlete'])[['City','Edition','Athlete','Sport']].head(10)
# Out:
#        City  Edition                   Athlete       Sport
# 7    Athens     1896          ANDREOU, Joannis    Aquatics
# 82   Athens     1896  ANDRIAKOPOULOS, Nicolaos  Gymnastics
# 110  Athens     1896  ANDRIAKOPOULOS, Nicolaos  Gymnastics
# 111  Athens     1896    ATHANASOPOULOS, Spyros  Gymnastics
# 48   Athens     1896            BATTEL, Edward     Cycling
# 19   Athens     1896             BLAKE, Arthur   Athletics
# 134  Athens     1896              BOLAND, John      Tennis
# 140  Athens     1896              BOLAND, John      Tennis
# 13   Athens     1896             BURKE, Thomas   Athletics
# 21   Athens     1896             BURKE, Thomas   Athletics

# %% [markdown]
# ### Boolean indexing

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# Getting all record for gold medals by womenoo
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')].head()
# Out:
#          City  Edition    Sport Discipline                Athlete  NOC Gender  \
# 417     Paris     1900     Golf       Golf  ABBOTT, Margaret Ives  USA  Women
# 641     Paris     1900   Tennis     Tennis      COOPER, Charlotte  GBR  Women
# 649     Paris     1900   Tennis     Tennis      COOPER, Charlotte  GBR  Women
# 710  St Louis     1904  Archery    Archery  HOWELL, Matilda Scott  USA  Women
# 713  St Louis     1904  Archery    Archery  HOWELL, Matilda Scott  USA  Women
#
#                                        Event Event_gender Medal
# 417                               individual            W  Gold
# 641                            mixed doubles            X  Gold
# 649                                  singles            W  Gold
# 710  double columbia round (50y - 40y - 30y)            W  Gold
# 713        double national round (60y - 50y)            W  Gold

# %% [markdown]
# ### String handling

# %%
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %% [markdown]
# ### In which events did Jesse Owens win a medal?

# %%
oo[oo.Athlete.str.contains('OWENS, Jesse')]
# oo[oo.Athlete.str.contains('OWENS, Jesse')].Event.value_counts()
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
jo = oo[oo['Athlete']=='OWENS, Jesse']
jo
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
jo.Event.value_counts()
# Out:
# 100m            1
# 200m            1
# 4x100m relay    1
# long jump       1
# Name: Event, dtype: int64

# %% [markdown]
# ### Which country has won the most men's gold medals in singles badminton over the years? Sort the results alphabetically by the player's  names.

# %%
#oo[(oo.Gender == 'Men') & (oo.Medal=='Gold') & (oo.Sport == 'Badminton') & (oo.Event == 'singles')].sort_values(by = 'Athlete')
gbm = oo[(oo.Gender == 'Men') & (oo.Medal=='Gold') & (oo.Sport == 'Badminton') & (oo.Event == 'singles')]

gbm.sort_values(by = 'Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
#
#       Gender    Event Event_gender Medal
# 20045    Men  singles            M  Gold
# 25734    Men  singles            M  Gold
# 21787    Men  singles            M  Gold
# 23717    Men  singles            M  Gold
# 27741    Men  singles            M  Gold

# %% [markdown]
# ### Which three countries have won the most medals in recent years (from 1984 to 2008)?

# %%
mmc = oo[oo.Edition >= 1984]

mmc.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %% [markdown]
# ### Display the male gold medal winners for the 100m Track & Field sprint event over the years. List the results starting with the most recent. Show the Olympic City, Edition, Athlete and the country they represent.

# %%
mg100 = oo[(oo.Gender == 'Men') & (oo.Medal == 'Gold') & (oo.Event == '100m')]
mg100[['City','Edition','Athlete','NOC']].sort_values(by=)
# Out:
#                         City  Edition                Athlete  NOC
# 13                    Athens     1896          BURKE, Thomas  USA
# 231                    Paris     1900        JARVIS, Francis  USA
# 737                 St Louis     1904           HAHN, Archie  USA
# 1191                  London     1908       WALKER, Reginald  RSA
# 2022               Stockholm     1912           CRAIG, Ralph  USA
# 2996                 Antwerp     1920       PADDOCK, Charles  USA
# 4236                   Paris     1924       ABRAHAMS, Harold  GBR
# 5095               Amsterdam     1928        WILLIAMS, Percy  CAN
# 5806             Los Angeles     1932           TOLAN, Eddie  USA
# 6427                  Berlin     1936           OWENS, Jesse  USA
# 7302                  London     1948      DILLARD, Harrison  USA
# 8121                Helsinki     1952        REMIGINO, Lindy  USA
# 9009   Melbourne / Stockholm     1956  MORROW, Robert Joseph  USA
# ...
